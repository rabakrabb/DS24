# %% [markdown]
# # SQLAlchemy och Pandas
#
# För att koppla ihop SQL-databasen med Python behöver vi använda ett bibliotek som heter SQLAlchemy. Dessutom behövs ett bibliotek som heter pyodbc för att hantera kopplingen mellan SQLAlchemy och SQL-servern.
#
# Du kan också behöva ladda ned och installera ODBC Driver 18 for SQL Server som du hittar här: https://learn.microsoft.com/en-us/sql/connect/odbc/download-odbc-driver-for-sql-server?view=sql-server-ver16
#
# Följande kodexempel bör fungera för att skapa en koppling mellan SQL-servern och en Jupyter Notebook för att utföra en query och läsa in resultatet som en Pandas `DataFrame` för vidare analys och visualisering.

# %%
# Installera bibliotek. Om du använder Anaconda är de antagligen redan installerade och du bör inte behöva inte köra den här koden.

! pip install sqlalchemy pyodbc pandas jupyter
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (2.0.36)
# Requirement already satisfied: pyodbc in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (5.2.0)
# Requirement already satisfied: pandas in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (2.2.2)
# Requirement already satisfied: jupyter in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (1.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from sqlalchemy) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: notebook in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyter) (7.2.2)
# Requirement already satisfied: jupyter-console in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyter) (7.10.0)
# Requirement already satisfied: ipykernel in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyter) (6.28.0)
# Requirement already satisfied: ipywidgets in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyter) (8.1.5)
# Requirement already satisfied: jupyterlab in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyter) (4.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from ipykernel->jupyter) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from ipykernel->jupyter) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from ipykernel->jupyter) (8.27.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from ipykernel->jupyter) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from ipykernel->jupyter) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from ipykernel->jupyter) (24.1)
# Requirement already satisfied: psutil in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from ipykernel->jupyter) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from ipykernel->jupyter) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from ipykernel->jupyter) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from ipywidgets->jupyter) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from ipywidgets->jupyter) (3.0.13)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyter-console->jupyter) (3.0.43)
# Requirement already satisfied: pygments in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyter-console->jupyter) (2.15.1)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyterlab->jupyter) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyterlab->jupyter) (0.27.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyterlab->jupyter) (3.1.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyterlab->jupyter) (2.2.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyterlab->jupyter) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyterlab->jupyter) (0.2.3)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyterlab->jupyter) (75.1.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from nbconvert->jupyter) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from nbconvert->jupyter) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from nbconvert->jupyter) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from nbconvert->jupyter) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from nbconvert->jupyter) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from nbconvert->jupyter) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from nbconvert->jupyter) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from nbconvert->jupyter) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from nbconvert->jupyter) (1.2.1)
# Requirement already satisfied: webencodings in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: anyio in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (4.2.0)
# Requirement already satisfied: certifi in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.0.2)
# Requirement already satisfied: idna in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (3.7)
# Requirement already satisfied: sniffio in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter) (0.14.0)
# Requirement already satisfied: decorator in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.1)
# Requirement already satisfied: stack-data in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: colorama in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (305.1)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.4.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.19.2)
# Requirement already satisfied: requests>=2.31 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.3)
# Requirement already satisfied: fastjsonschema in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.5)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.10.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.2.2)
# Requirement already satisfied: executing in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: fqdn in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\rabad\anaconda3\envs\python_course\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.2.3)

# %%
# Importer

from sqlalchemy.engine import create_engine, URL
import pandas as pd

# %%
SERVER = 'localhost'  # localhost innebär att du ansluter till en server på din egen dator
DATABASE = 'AdventureWorks2022'

connection_string = f'DRIVER={{ODBC Driver 18 for SQL Server}};SERVER={SERVER};DATABASE={DATABASE};Trusted_Connection=yes;Encrypt=no'

connection_url = URL.create('mssql+pyodbc', query={'odbc_connect': connection_string})

engine = create_engine(connection_url)  # engine är anslutningsobjektet vi använder för att kommunicera med databasen.

# %%
# Skriv en query. Använd trippla citationstecken runt textsträngen för att kunna ha radbrytningar i den.

query = """SELECT * FROM Production.Product
"""

# Skapa en DataFrame med resultaten av queryn.
products_df = pd.read_sql(query, engine)

# %%
products_df
# Out:
#      ProductID                   Name ProductNumber  MakeFlag  \
# 0            1        Adjustable Race       AR-5381     False
# 1            2           Bearing Ball       BA-8327     False
# 2            3        BB Ball Bearing       BE-2349      True
# 3            4  Headset Ball Bearings       BE-2908     False
# 4          316                  Blade       BL-2036      True
# ..         ...                    ...           ...       ...
# 499        995      ML Bottom Bracket       BB-8107      True
# 500        996      HL Bottom Bracket       BB-9108      True
# 501        997     Road-750 Black, 44    BK-R19B-44      True
# 502        998     Road-750 Black, 48    BK-R19B-48      True
# 503        999     Road-750 Black, 52    BK-R19B-52      True
#
#      FinishedGoodsFlag  Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0                False   None              1000           750        0.0000
# 1                False   None              1000           750        0.0000
# 2                False   None               800           600        0.0000
# 3                False   None               800           600        0.0000
# 4                False   None               800           600        0.0000
# ..                 ...    ...               ...           ...           ...
# 499               True   None               500           375       44.9506
# 500               True   None               500           375       53.9416
# 501               True  Black               100            75      343.6496
# 502               True  Black               100            75      343.6496
# 503               True  Black               100            75      343.6496
#
#      ListPrice  ... ProductLine Class Style  ProductSubcategoryID  \
# 0         0.00  ...        None  None  None                   NaN
# 1         0.00  ...        None  None  None                   NaN
# 2         0.00  ...        None  None  None                   NaN
# 3         0.00  ...        None  None  None                   NaN
# 4         0.00  ...        None  None  None                   NaN
# ..         ...  ...         ...   ...   ...                   ...
# 499     101.24  ...        None    M   None                   5.0
# 500     121.49  ...        None    H   None                   5.0
# 501     539.99  ...          R     L     U                    2.0
# 502     539.99  ...          R     L     U                    2.0
# 503     539.99  ...          R     L     U                    2.0
#
#      ProductModelID SellStartDate SellEndDate DiscontinuedDate  \
# 0               NaN    2008-04-30         NaT             None
# 1               NaN    2008-04-30         NaT             None
# 2               NaN    2008-04-30         NaT             None
# 3               NaN    2008-04-30         NaT             None
# 4               NaN    2008-04-30         NaT             None
# ..              ...           ...         ...              ...
# 499            96.0    2013-05-30         NaT             None
# 500            97.0    2013-05-30         NaT             None
# 501            31.0    2013-05-30         NaT             None
# 502            31.0    2013-05-30         NaT             None
# 503            31.0    2013-05-30         NaT             None
#
#                                   rowguid            ModifiedDate
# 0    694215B7-08F7-4C0D-ACB1-D734BA44C0C8 2014-02-08 10:01:36.827
# 1    58AE3C20-4F3A-4749-A7D4-D568806CC537 2014-02-08 10:01:36.827
# 2    9C21AED2-5BFA-4F18-BCB8-F11638DC2E4E 2014-02-08 10:01:36.827
# 3    ECFED6CB-51FF-49B5-B06C-7D8AC834DB8B 2014-02-08 10:01:36.827
# 4    E73E9750-603B-4131-89F5-3DD15ED5FF80 2014-02-08 10:01:36.827
# ..                                    ...                     ...
# 499  71AB847F-D091-42D6-B735-7B0C2D82FC84 2014-02-08 10:01:36.827
# 500  230C47C5-08B2-4CE3-B706-69C0BDD62965 2014-02-08 10:01:36.827
# 501  44CE4802-409F-43AB-9B27-CA53421805BE 2014-02-08 10:01:36.827
# 502  3DE9A212-1D49-40B6-B10A-F564D981DBDE 2014-02-08 10:01:36.827
# 503  AE638923-2B67-4679-B90E-ABBAB17DCA31 2014-02-08 10:01:36.827
#
# [504 rows x 25 columns]

# %%
import redis

r = redis.Redis(
    host='<redis host för din skapade instans>',
    port='<din port>',
    password='<ditt personliga lösenord>')
